# %%
import torch
import os
import wandb
import numpy as np
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
from datetime import datetime

input_mean = np.load("/home/metamobility2/JiminMM2/training_code_resumable_FlexPositive_selective/SI_AB01_Jimin_Selective/input_mean.npy")
input_std = np.load("/home/metamobility2/JiminMM2/training_code_resumable_FlexPositive_selective/SI_AB01_Jimin_Selective/input_std.npy")
label_mean = np.load("/home/metamobility2/JiminMM2/training_code_resumable_FlexPositive_selective/SI_AB01_Jimin_Selective/label_mean.npy")
label_std = np.load("/home/metamobility2/JiminMM2/training_code_resumable_FlexPositive_selective/SI_AB01_Jimin_Selective/label_std.npy")

print(f"Input mean : {input_mean}")
print(f"Input std : {input_std}")
print(f"Label mean : {label_mean}")
print(f"Label std : {label_std}")
# Out:
# Input mean : [ -9.72489289  -0.64503637   1.01597175  -1.39475123   0.01905674
#   -2.2353814  -14.61049136  -0.76010473]
# Input std : [ 2.61149042  1.81299289  3.21879337 20.36555259 69.33492588 15.79112283
#  17.37058176 82.51050539]
# Label mean : [0.00031531]
# Label std : [0.22618309]

# %%
input_mean = np.load("/home/metamobility2/JiminMM2/SI_AB01_Jimin_LGRARD_EntireDataset_Corrected_FlexPositive/input_mean.npy")
input_std = np.load("/home/metamobility2/JiminMM2/SI_AB01_Jimin_LGRARD_EntireDataset_Corrected_FlexPositive/input_std.npy")
label_mean = np.load("/home/metamobility2/JiminMM2/SI_AB01_Jimin_LGRARD_EntireDataset_Corrected_FlexPositive/label_mean.npy")
label_std = np.load("/home/metamobility2/JiminMM2/SI_AB01_Jimin_LGRARD_EntireDataset_Corrected_FlexPositive/label_std.npy")

print(f"Input mean : {input_mean}")
print(f"Input std : {input_std}")
print(f"Label mean : {label_mean}")
print(f"Label std : {label_std}")
# Out:
# Input mean : [ -9.72489289  -0.64503637   1.01597175  -1.39475123   0.01905674
#   -2.2353814  -14.61049136  -0.76010473]
# Input std : [ 2.61149042  1.81299289  3.21879337 20.36555259 69.33492588 15.79112283
#  17.37058176 82.51050539]
# Label mean : [-0.0008627]
# Label std : [0.26465187]
